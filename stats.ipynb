# %%
import RL
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats
# Out:
# Using TensorFlow backend.

# %%
RL_train_reward, RL_test_reward, SL_train_reward, SL_test_reward = RL.main(100)
# Out:
# Start creating features from order books and transactions data
# Finished creating features, time lapse: 0.166 seconds
# /Users/yanyunfeng/PycharmProjects/AlgoTrading/features.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   flow['buy_vol'] = 0
# /Users/yanyunfeng/PycharmProjects/AlgoTrading/features.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   flow['sell_vol'] = 0
# /Users/yanyunfeng/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:966: SettingWithCopyWarning:
# ...

# %%
RL_mean = np.mean(RL_test_reward)
SL_mean = np.mean(SL_test_reward)
RL_test_reward[RL_test_reward<-2.5]=RL_mean
SL_test_reward[SL_test_reward<-2.5]=SL_mean
plt.plot(RL_test_reward,label='RL_test')
plt.plot(SL_test_reward,label='SL_test')
plt.legend()

# %%
RL_mean,SL_mean
# Out:
# (-0.035997833935018625, -0.02549160649819348)

# %%
plt.plot(RL_test_reward.cumsum(),label='RL_test')
plt.plot(SL_test_reward.cumsum(),label='SL_test')
plt.legend()

# %%
scipy.stats.ttest_ind(RL_test_reward, SL_test_reward)
# Out:
# Ttest_indResult(statistic=1.7801774748559374, pvalue=0.07532139473117615)
